# %%
# !pip install -q efficientnet

# %%
# !pip install transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (4.26.1)
# Requirement already satisfied: numpy>=1.17 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from transformers) (1.24.2)
# Requirement already satisfied: filelock in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from transformers) (3.9.0)
# Requirement already satisfied: tqdm>=4.27 in /Library/Python/3.9/site-packages (from transformers) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from transformers) (0.12.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from transformers) (2.28.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (3.0.1)

# %%
# !pip install albumentations
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: albumentations in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (1.3.0)
# Requirement already satisfied: scikit-image>=0.16.1 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from albumentations) (0.19.3)
# Requirement already satisfied: qudida>=0.0.4 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from albumentations) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from albumentations) (4.7.0.72)
# Requirement already satisfied: scipy in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from albumentations) (1.10.0)
# Requirement already satisfied: PyYAML in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from albumentations) (6.0)
# Requirement already satisfied: numpy>=1.11.1 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from albumentations) (1.24.2)
# Requirement already satisfied: scikit-learn>=0.19.1 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from qudida>=0.0.4->albumentations) (1.2.1)
# Requirement already satisfied: typing-extensions in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from qudida>=0.0.4->albumentations) (4.5.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from scikit-image>=0.16.1->albumentations) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from scikit-image>=0.16.1->albumentations) (23.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /Library/Python/3.9/site-packages (from scikit-image>=0.16.1->albumentations) (9.4.0)
# Requirement already satisfied: networkx>=2.2 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from scikit-image>=0.16.1->albumentations) (3.0)
# Requirement already satisfied: imageio>=2.4.1 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from scikit-image>=0.16.1->albumentations) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from scikit-image>=0.16.1->albumentations) (2023.2.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (1.2.0)

# %%
# !pip install kaggle
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: kaggle in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from kaggle) (1.15.0)
# Requirement already satisfied: requests in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from kaggle) (2.28.2)
# Requirement already satisfied: urllib3 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from kaggle) (1.26.14)
# Requirement already satisfied: python-slugify in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from kaggle) (8.0.1)
# Requirement already satisfied: certifi in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from kaggle) (2022.12.7)
# Requirement already satisfied: tqdm in /Library/Python/3.9/site-packages (from kaggle) (4.64.1)
# Requirement already satisfied: python-dateutil in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from requests->kaggle) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/harithatamvada/Library/Python/3.9/lib/python/site-packages (from requests->kaggle) (3.0.1)

# %%
import os
import cv2
import math
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as tqdm
from sklearn.metrics import confusion_matrix,accuracy_score,roc_auc_score,precision_score,recall_score,ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split,KFold,StratifiedKFold
from transformers import get_cosine_schedule_with_warmup
from albumentations import *
#from kaggle_datasets import KaggleDatasets

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras import optimizers
import efficientnet.tfkeras as efn
from albumentations import *

# %%
AUTO = tf.data.experimental.AUTOTUNE

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy()
    
print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# REPLICAS:  1

# %%
SEED = 42
BATCH_SIZE = 8 * strategy.num_replicas_in_sync
#BATCH_SIZE = 8 * 8
SIZE = [224,224]
LR = 0.0008
WEIGHT_DECAY = 0
EPOCHS = 40
WARMUP = 15
TTA = 4

# %%
def seed_everything(SEED):
    np.random.seed(SEED)
    tf.random.set_seed(SEED)

seed_everything(SEED)

# %%
DIR_INPUT = '/Users/harithatamvada/soil-classification/'
train_df = pd.read_csv(DIR_INPUT + '/train3.csv')
test_df = pd.read_csv(DIR_INPUT + '/train3.csv')
cols = list(train_df.columns[1:])

# %%
train_df.head()
# Out:
#   image_id  sand  silt  clay  loam
# 0  Sample1     0     0     1     0
# 1  Sample2     0     0     1     0
# 2  Sample3     0     0     1     0
# 3  Sample4     0     0     1     0
# 4  Sample5     0     0     1     0

# %%
train,valid = train_test_split(train_df,test_size = 0.2,random_state = SEED)

# %%
transform = {
    'train' :Compose([
        Resize(SIZE[0],SIZE[1],always_apply=True),
        HorizontalFlip(p=0.5),
        VerticalFlip(p=0.5),
        RandomRotate90(p=0.5),
        Rotate(limit=25.0,p=0.8)]) }

def preprocess(df,test=False):
    paths = df.image_id.apply(lambda x: '/Users/harithatamvada/soil-classification' + '/images2/' + x + '.jpg').values
    labels = df.loc[:,'loam':].values
    if test==False:
        return paths,labels
    else:
        return paths
    
def decode_image(filename, label=None, image_size=(SIZE[0], SIZE[1])):
    bits = tf.io.read_file(filename)
    image = tf.image.decode_jpeg(bits, channels=3) 
    image = tf.image.resize(image, image_size)
    image = tf.cast(image, tf.float32)
    image = tf.image.per_image_standardization(image)
    if label is None:
        return image
    else:
        return image, label
    
def data_augment(image, label=None, seed=SEED):
    image = tf.image.rot90(image,k=np.random.randint(4))
    image = tf.image.random_flip_left_right(image, seed=seed)
    image = tf.image.random_flip_up_down(image, seed=seed)
    if label is None:
        return image
    else:
        return image, label
    
def albu(image):
    transforms = transform['train']
    image = transforms(image=image.numpy())['image']
    image = tf.cast(image, tf.float32)
    return image
    
def albu_fn(image,label=None):
    [image,] = tf.py_function(albu, [image], [tf.float32])
    if label is None:
        return image
    else:
        return image, label

# %%
train_dataset = (tf.data.Dataset
    .from_tensor_slices(preprocess(train))
    .map(decode_image, num_parallel_calls=AUTO)
    .map(data_augment, num_parallel_calls=AUTO)
    .shuffle(SEED)
    .batch(BATCH_SIZE,drop_remainder=True)
    .repeat()
    .prefetch(AUTO))

valid_dataset = (tf.data.Dataset
    .from_tensor_slices(preprocess(valid))
    .map(decode_image, num_parallel_calls=AUTO)
    .batch(BATCH_SIZE)
    .cache()
    .prefetch(AUTO))

test_dataset = (tf.data.Dataset
    .from_tensor_slices(preprocess(test_df,test=True))
    .map(decode_image, num_parallel_calls=AUTO)
    .batch(BATCH_SIZE))
# Out:
# Metal device set to: Apple M2
# 2023-02-25 15:57:03.732470: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-02-25 15:57:03.732965: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
def plot_transform(image_id,num_images=7):
    plt.figure(figsize=(30,10))
    path,_ = preprocess(train.iloc[image_id:image_id+1])
    for i in range(1,num_images+1):
        plt.subplot(1,num_images+1,i)
        plt.axis('off')
        image = decode_image(filename=path[0])
        image = data_augment(image=image)
        plt.imshow(image)

plot_transform(9)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model = tf.keras.Sequential([
    efn.EfficientNetB0(input_shape=(SIZE[0], SIZE[1], 3),weights='imagenet',pooling='avg',include_top=False),
    Dense(2, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss = 'sparse_categorical_crossentropy',
    metrics=['categorical_accuracy'])

# %%
def get_cosine_schedule_with_warmup(lr,num_warmup_steps, num_training_steps, num_cycles=0.5):
    """
    Modified the get_cosine_schedule_with_warmup from huggingface for tenserflow
    (https://huggingface.co/transformers/_modules/transformers/optimization.html#get_cosine_schedule_with_warmup)

    Create a schedule with a learning rate that decreases following the
    values of the cosine function between 0 and `pi * cycles` after a warmup
    period during which it increases linearly between 0 and 1.
    """

    def lrfn(epoch):
        if epoch < num_warmup_steps:
            return float(epoch) / float(max(1, num_warmup_steps)) * lr
        progress = float(epoch - num_warmup_steps) / float(max(1, num_training_steps - num_warmup_steps))
        return max(0.0, 0.5 * (1.0 + math.cos(math.pi * float(num_cycles) * 2.0 * progress))) * lr

    return tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=True)

lr_schedule= get_cosine_schedule_with_warmup(lr=LR,num_warmup_steps=WARMUP,num_training_steps=EPOCHS)

# %%
STEPS_PER_EPOCH = train.shape[0] // BATCH_SIZE

def train():
    history = model.fit(
        train_dataset, 
        epochs=EPOCHS, 
        callbacks=[lr_schedule],
        steps_per_epoch=STEPS_PER_EPOCH,
        validation_data=valid_dataset)
    
    string = 'Train acc:{:.4f} Train loss:{:.4f},Val acc:{:.4f} Val loss:{:.4f}'.format( \
        model.history.history['categorical_accuracy'][-1],model.history.history['loss'][-1],\
        model.history.history['val_categorical_accuracy'][-1],model.history.history['val_loss'][-1])
    
    return string

# %%
train()
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0.
# Epoch 1/40
# 2023-02-25 15:57:15.693968: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-02-25 15:57:15.698305: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 12/12 [==============================] - ETA: 0s - loss: 0.8091 - categorical_accuracy: 0.3438
# 2023-02-25 15:57:20.615097: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 12/12 [==============================] - 8s 292ms/step - loss: 0.8091 - categorical_accuracy: 0.3438 - val_loss: 0.9953 - val_categorical_accuracy: 0.2308 - lr: 0.0000e+00
#
# Epoch 2: LearningRateScheduler setting learning rate to 5.333333333333333e-05.
# Epoch 2/40
# 12/12 [==============================] - 2s 182ms/step - loss: 0.7099 - categorical_accuracy: 0.4896 - val_loss: 0.8448 - val_categorical_accuracy: 0.3077 - lr: 5.3333e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.00010666666666666667.
# Epoch 3/40
# 12/12 [==============================] - 2s 181ms/step - loss: 0.4121 - categorical_accuracy: 0.7604 - val_loss: 0.5616 - val_categorical_accuracy: 0.8462 - lr: 1.0667e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.00016.
# Epoch 4/40
# 12/12 [==============================] - 2s 173ms/step - loss: 0.2646 - categorical_accuracy: 0.7708 - val_loss: 0.3430 - val_categorical_accuracy: 0.8462 - lr: 1.6000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.00021333333333333333.
# Epoch 5/40
# 12/12 [==============================] - 2s 175ms/step - loss: 0.1486 - categorical_accuracy: 0.7708 - val_loss: 0.2606 - val_categorical_accuracy: 0.8462 - lr: 2.1333e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0002666666666666667.
# Epoch 6/40
# 12/12 [==============================] - 2s 170ms/step - loss: 0.0823 - categorical_accuracy: 0.8021 - val_loss: 0.1195 - val_categorical_accuracy: 0.9231 - lr: 2.6667e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.00032.
# Epoch 7/40
# 12/12 [==============================] - 2s 177ms/step - loss: 0.0856 - categorical_accuracy: 0.7917 - val_loss: 0.0640 - val_categorical_accuracy: 0.9231 - lr: 3.2000e-04
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0003733333333333334.
# Epoch 8/40
# 12/12 [==============================] - 2s 180ms/step - loss: 0.0872 - categorical_accuracy: 0.7708 - val_loss: 0.5216 - val_categorical_accuracy: 0.6538 - lr: 3.7333e-04
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.00042666666666666667.
# Epoch 9/40
# 12/12 [==============================] - 2s 174ms/step - loss: 0.0514 - categorical_accuracy: 0.7708 - val_loss: 0.2454 - val_categorical_accuracy: 0.8462 - lr: 4.2667e-04
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.00048.
# Epoch 10/40
# 12/12 [==============================] - 2s 170ms/step - loss: 0.0511 - categorical_accuracy: 0.7604 - val_loss: 0.1201 - val_categorical_accuracy: 0.8846 - lr: 4.8000e-04
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0005333333333333334.
# Epoch 11/40
# 12/12 [==============================] - 2s 168ms/step - loss: 0.0598 - categorical_accuracy: 0.7917 - val_loss: 0.1389 - val_categorical_accuracy: 0.8846 - lr: 5.3333e-04
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0005866666666666667.
# Epoch 12/40
# 12/12 [==============================] - 2s 173ms/step - loss: 0.0427 - categorical_accuracy: 0.7604 - val_loss: 0.1069 - val_categorical_accuracy: 0.8846 - lr: 5.8667e-04
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.00064.
# Epoch 13/40
# 12/12 [==============================] - 2s 171ms/step - loss: 0.0800 - categorical_accuracy: 0.7917 - val_loss: 0.0519 - val_categorical_accuracy: 0.8846 - lr: 6.4000e-04
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0006933333333333333.
# Epoch 14/40
# 12/12 [==============================] - 2s 169ms/step - loss: 0.0785 - categorical_accuracy: 0.7812 - val_loss: 0.7744 - val_categorical_accuracy: 0.5769 - lr: 6.9333e-04
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0007466666666666667.
# Epoch 15/40
# 12/12 [==============================] - 2s 171ms/step - loss: 0.1362 - categorical_accuracy: 0.7188 - val_loss: 0.0763 - val_categorical_accuracy: 0.8846 - lr: 7.4667e-04
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0008.
# Epoch 16/40
# 12/12 [==============================] - 2s 169ms/step - loss: 0.1956 - categorical_accuracy: 0.7188 - val_loss: 0.3972 - val_categorical_accuracy: 0.7692 - lr: 8.0000e-04
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0007968458805257912.
# Epoch 17/40
# 12/12 [==============================] - 2s 170ms/step - loss: 0.0805 - categorical_accuracy: 0.7812 - val_loss: 0.0053 - val_categorical_accuracy: 0.9231 - lr: 7.9685e-04
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0007874332644514524.
# Epoch 18/40
# 12/12 [==============================] - 2s 172ms/step - loss: 0.1557 - categorical_accuracy: 0.7812 - val_loss: 0.0618 - val_categorical_accuracy: 0.9615 - lr: 7.8743e-04
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.0007719105943553005.
# Epoch 19/40
# 12/12 [==============================] - 2s 169ms/step - loss: 0.1330 - categorical_accuracy: 0.7917 - val_loss: 0.2520 - val_categorical_accuracy: 1.0000 - lr: 7.7191e-04
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.0007505226720175454.
# Epoch 20/40
# 12/12 [==============================] - 2s 168ms/step - loss: 0.1061 - categorical_accuracy: 0.7604 - val_loss: 0.0743 - val_categorical_accuracy: 0.9615 - lr: 7.5052e-04
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.000723606797749979.
# Epoch 21/40
# 12/12 [==============================] - 2s 169ms/step - loss: 0.1834 - categorical_accuracy: 0.7396 - val_loss: 0.0060 - val_categorical_accuracy: 0.9231 - lr: 7.2361e-04
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0006915874509685647.
# Epoch 22/40
# 12/12 [==============================] - 2s 174ms/step - loss: 0.1998 - categorical_accuracy: 0.7604 - val_loss: 0.0010 - val_categorical_accuracy: 0.9231 - lr: 6.9159e-04
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.000654969595899476.
# Epoch 23/40
# 12/12 [==============================] - 2s 169ms/step - loss: 0.1133 - categorical_accuracy: 0.7812 - val_loss: 6.0637e-05 - val_categorical_accuracy: 0.9231 - lr: 6.5497e-04
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.0006143307179915986.
# Epoch 24/40
# 12/12 [==============================] - 2s 168ms/step - loss: 0.0852 - categorical_accuracy: 0.8125 - val_loss: 3.4548e-04 - val_categorical_accuracy: 0.9231 - lr: 6.1433e-04
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.0005703117166260291.
# Epoch 25/40
# 12/12 [==============================] - 2s 168ms/step - loss: 0.0589 - categorical_accuracy: 0.7604 - val_loss: 0.0018 - val_categorical_accuracy: 0.9231 - lr: 5.7031e-04
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.0005236067977499791.
# Epoch 26/40
# 12/12 [==============================] - 2s 171ms/step - loss: 0.0541 - categorical_accuracy: 0.7812 - val_loss: 0.0019 - val_categorical_accuracy: 0.9231 - lr: 5.2361e-04
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.00047495252583428996.
# Epoch 27/40
# 12/12 [==============================] - 2s 168ms/step - loss: 0.0193 - categorical_accuracy: 0.7917 - val_loss: 4.2903e-04 - val_categorical_accuracy: 0.9231 - lr: 4.7495e-04
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.0004251162078117254.
# Epoch 28/40
# 12/12 [==============================] - 2s 170ms/step - loss: 0.0249 - categorical_accuracy: 0.7812 - val_loss: 0.0038 - val_categorical_accuracy: 0.9231 - lr: 4.2512e-04
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.0003748837921882747.
# Epoch 29/40
# 12/12 [==============================] - 2s 170ms/step - loss: 0.0258 - categorical_accuracy: 0.7708 - val_loss: 0.0056 - val_categorical_accuracy: 0.9231 - lr: 3.7488e-04
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.0003250474741657101.
# Epoch 30/40
# 12/12 [==============================] - 2s 167ms/step - loss: 0.0738 - categorical_accuracy: 0.7500 - val_loss: 0.0024 - val_categorical_accuracy: 0.9231 - lr: 3.2505e-04
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.0002763932022500211.
# Epoch 31/40
# 12/12 [==============================] - 2s 168ms/step - loss: 0.0154 - categorical_accuracy: 0.7917 - val_loss: 0.0086 - val_categorical_accuracy: 0.9231 - lr: 2.7639e-04
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.00022968828337397094.
# Epoch 32/40
# 12/12 [==============================] - 2s 168ms/step - loss: 0.0480 - categorical_accuracy: 0.8021 - val_loss: 0.0222 - val_categorical_accuracy: 0.9231 - lr: 2.2969e-04
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.00018566928200840126.
# Epoch 33/40
# 12/12 [==============================] - 2s 168ms/step - loss: 0.0113 - categorical_accuracy: 0.7604 - val_loss: 0.0171 - val_categorical_accuracy: 0.9231 - lr: 1.8567e-04
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.0001450304041005241.
# Epoch 34/40
# 12/12 [==============================] - 2s 168ms/step - loss: 0.0069 - categorical_accuracy: 0.7708 - val_loss: 0.0208 - val_categorical_accuracy: 0.9231 - lr: 1.4503e-04
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.00010841254903143547.
# Epoch 35/40
# 12/12 [==============================] - 2s 168ms/step - loss: 0.0049 - categorical_accuracy: 0.7812 - val_loss: 0.0199 - val_categorical_accuracy: 0.9231 - lr: 1.0841e-04
#
# Epoch 36: LearningRateScheduler setting learning rate to 7.639320225002106e-05.
# Epoch 36/40
# 12/12 [==============================] - 2s 169ms/step - loss: 0.0044 - categorical_accuracy: 0.7917 - val_loss: 0.0222 - val_categorical_accuracy: 0.9231 - lr: 7.6393e-05
#
# Epoch 37: LearningRateScheduler setting learning rate to 4.947732798245466e-05.
# Epoch 37/40
# 12/12 [==============================] - 2s 169ms/step - loss: 0.0117 - categorical_accuracy: 0.8021 - val_loss: 0.0239 - val_categorical_accuracy: 0.9231 - lr: 4.9477e-05
#
# Epoch 38: LearningRateScheduler setting learning rate to 2.8089405644699463e-05.
# Epoch 38/40
# 12/12 [==============================] - 2s 170ms/step - loss: 0.0034 - categorical_accuracy: 0.7812 - val_loss: 0.0267 - val_categorical_accuracy: 0.9231 - lr: 2.8089e-05
#
# Epoch 39: LearningRateScheduler setting learning rate to 1.256673554854757e-05.
# Epoch 39/40
# 12/12 [==============================] - 2s 169ms/step - loss: 0.0103 - categorical_accuracy: 0.7708 - val_loss: 0.0272 - val_categorical_accuracy: 0.9231 - lr: 1.2567e-05
#
# Epoch 40: LearningRateScheduler setting learning rate to 3.154119474208894e-06.
# Epoch 40/40
# 12/12 [==============================] - 2s 169ms/step - loss: 0.0033 - categorical_accuracy: 0.7708 - val_loss: 0.0297 - val_categorical_accuracy: 0.8846 - lr: 3.1541e-06
# 'Train acc:0.7708 Train loss:0.0033,Val acc:0.8846 Val loss:0.0297'

# %%
def display_training_curves(training, validation, title, subplot):
    """
    Source: https://www.kaggle.com/mgornergoogle/getting-started-with-100-flowers-on-tpu
    """
    if subplot%10==1: # set up the subplots on the first call
        plt.subplots(figsize=(15,15), facecolor='#F0F0F0')
        plt.tight_layout()
    ax = plt.subplot(subplot)
    ax.set_facecolor('#F8F8F8')
    ax.plot(training)
    ax.plot(validation)
    ax.set_title('model '+ title)
    ax.set_ylabel(title)
    ax.set_xlabel('epoch')
    ax.legend(['train', 'valid.'])

# %%
display_training_curves(
    model.history.history['loss'], 
    model.history.history['val_loss'], 
    'loss', 211)
display_training_curves(
    model.history.history['categorical_accuracy'], 
    model.history.history['val_categorical_accuracy'], 
    'accuracy', 212)
# Out:
# /var/folders/rq/fttfpph53671nf5_9s4qnwlm0000gn/T/ipykernel_59458/1133020224.py:8: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax = plt.subplot(subplot)

# %%
from PIL import Image

test_image=r'/Users/harithatamvada/soil-classification/images2/test/5.jpg'
image_result=Image.open(test_image)

from tensorflow.keras.preprocessing import image
test_image=image.load_img(test_image,target_size=(224,224))
test_image=image.img_to_array(test_image)
test_image=test_image/255
test_image=np.expand_dims(test_image,axis=0)
result=model.predict(test_image)
print(np.argmax(result))
Categories=['clay', 'sand', 'loam', 'silt']
image_result=plt.imshow(image_result)
plt.title(Categories[np.argmax(result)])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       8 test_image=image.img_to_array(test_image)
#       9 test_image=test_image/255
# ---> 10 test_image=np.expand_dims(test_image,axis=0)
#      11 result=model.predict(test_image)
#      12 print(np.argmax(result))
#
# NameError: name 'np' is not defined

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open("model.tflite", 'wb') as f:
  f.write(tflite_model)
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) efficientnet-b0_input with unsupported characters which will be renamed to efficientnet_b0_input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 81). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /var/folders/rq/fttfpph53671nf5_9s4qnwlm0000gn/T/tmpjjq81ba2/assets
# INFO:tensorflow:Assets written to: /var/folders/rq/fttfpph53671nf5_9s4qnwlm0000gn/T/tmpjjq81ba2/assets
# 2023-02-25 12:45:02.915173: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2023-02-25 12:45:02.915189: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# 2023-02-25 12:45:02.915612: I tensorflow/cc/saved_model/reader.cc:43] Reading SavedModel from: /var/folders/rq/fttfpph53671nf5_9s4qnwlm0000gn/T/tmpjjq81ba2
# 2023-02-25 12:45:02.941308: I tensorflow/cc/saved_model/reader.cc:81] Reading meta graph with tags { serve }
# 2023-02-25 12:45:02.941316: I tensorflow/cc/saved_model/reader.cc:122] Reading SavedModel debug info (if present) from: /var/folders/rq/fttfpph53671nf5_9s4qnwlm0000gn/T/tmpjjq81ba2
# 2023-02-25 12:45:03.020126: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# 2023-02-25 12:45:03.036544: I tensorflow/cc/saved_model/loader.cc:228] Restoring SavedModel bundle.
# 2023-02-25 12:45:03.544168: I tensorflow/cc/saved_model/loader.cc:212] Running initialization op on SavedModel bundle at path: /var/folders/rq/fttfpph53671nf5_9s4qnwlm0000gn/T/tmpjjq81ba2
# 2023-02-25 12:45:03.694402: I tensorflow/cc/saved_model/loader.cc:301] SavedModel load for tags { serve }; Status: success: OK. Took 778798 microseconds.
# 2023-02-25 12:45:03.989641: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:263] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
